# %% [markdown]
# # LAB 2.4 - Model instrumentation

# %%
# !wget -nc --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/2021.deeplearning/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
from local.lib.rlxmoocapi import submit, session
import inspect
session.LoginSequence(endpoint=init.endpoint, course_id=init.course_id, lab_id="L02.04", varname="student");
# Out:
# logging in as nlninosi@unal.edu.co... please wait
# using course session deeplearning.unal::intro_si_2022_2
# success!! you are logged in

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras
from IPython.display import Image
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ### LAB SUMMARY
#
#
# In this lab you will be implementing Tensorflow Callbacks that will be invoked at different stages when a model gets trained.
#
# Read carefully the following tutorial: [https://www.tensorflow.org/guide/keras/custom_callback](https://www.tensorflow.org/guide/keras/custom_callback)
#
#
# ### load sample MNIST data as customary

# %%
mnist = pd.read_csv("local/data/mnist1.5k.csv.gz", compression="gzip", header=None).values
X=mnist[:,1:785]/255.
y=mnist[:,0]
print("dimension de las imagenes y las clases", X.shape, y.shape)
# Out:
# dimension de las imagenes y las clases (1500, 784) (1500,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
X_train = X_train.astype(np.float32)
X_test  = X_test.astype(np.float32)
y_train_oh = np.eye(10)[y_train]
y_test_oh  = np.eye(10)[y_test]
print(X_train.shape, y_train_oh.shape)
# Out:
# (1200, 784) (1200, 10)

# %%
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import Callback

# %% [markdown]
# ### A basic multi layered dense model
#
# observe that the function allows us to parametrize the number of hidden layers and their activation function

# %%
def get_model(input_dim=784, output_dim=10, num_hidden_layers=6, hidden_size=10, activation="relu"):

    model = Sequential()
    model.add(Dense(hidden_size, activation=activation, input_dim=input_dim, name="Layer_%02d_Input"%(0)))

    for i in range(num_hidden_layers):
        model.add(Dense(hidden_size, activation=activation, name="Layer_%02d_Hidden"%(i+1)))

    model.add(Dense(output_dim, activation="softmax", name="Layer_%02d_Output"%(num_hidden_layers+1)))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# ## TASK 1: Weights monitoring callback
#
# Create a callback that:
#
# - when each epoch ends, retrieves the weights of the layer with name `self.layer_name`.
# - gets is kernels weights.
# - computes the mean and standard deviation of those weights.
# - appends them to `self.mean_per_epoch` and `self.std_per_epoch`
#
# When used with a model, at the end of any training it will contain a list of weights means and another list of weights stds, both with one element per each epoch. With this we can monitor how the weights in a specific layer progress over the training process. Tensorboard offers a similar functionality, but the goal with this task is to get acquainted with the callback mechanism.

# %%
def LayerWeightsCallback(layer_name):
    class LayerWeightsCallback_class(Callback):

        def __init__(self, layer_name):
            super().__init__()
            self.mean_per_epoch = []
            self.std_per_epoch = []
            self.layer_name = layer_name

        def on_epoch_end(self, epoch, logs=None):
            w = self.model.get_layer(self.layer_name).get_weights() # get the weights from layer_name in self.model
            #print("w: ", w[0])
            self.mean_per_epoch.append(np.mean(w[0])) # append to self.mean_per_epoch the weights mean
            self.std_per_epoch.append(np.std(w[0])) # append to self.std_per_epoch the weights std

    return LayerWeightsCallback_class(layer_name)

# %% [markdown]
# manually test your code with the following cell. Your callback should report the weights mean and std doubling at every epoch, just with the same values as they are being computed within the for loop. The loop simulates training epochs.

# %%
model = get_model(input_dim=2, output_dim=3, num_hidden_layers=1, hidden_size=2, activation="sigmoid")
layer_names = [i.name for i in model.layers if not "Input" in i.name]
layer = model.get_layer(np.random.choice(layer_names))

cb = LayerWeightsCallback(layer.name)
cb.model = model

m, s, wh = [], [], []
for epoch in range(3):
    w = layer.get_weights()[0]
    wh.append(w)
    print ("epoch", epoch, "weights mean/std", np.mean(w),np.std(w))
    cb.on_epoch_end(epoch)
    layer.set_weights([i*2 for i in layer.get_weights()])

print ("\nweight mean at each epoch", cb.mean_per_epoch)
print ("weight std  at each epoch", cb.std_per_epoch)
# Out:
# epoch 0 weights mean/std 0.23048058 0.3707581
# epoch 1 weights mean/std 0.46096116 0.7415162
# epoch 2 weights mean/std 0.9219223 1.4830323
#
# weight mean at each epoch [0.23048058, 0.46096116, 0.9219223]
# weight std  at each epoch [0.3707581, 0.7415162, 1.4830323]

# %% [markdown]
# Now you can use your class to keep track of weights while training. We choose to keep track of weights with your callback for all the layers.
#
# Observe how we plot the weights progress with the data gathered by your callback. What interpretation can you give to the plots?

# %%
model = get_model(num_hidden_layers=3, activation="sigmoid")
cbs = [LayerWeightsCallback(i.name) for i in model.layers]
model.fit(X_train, y_train_oh, epochs=100, batch_size=8,
          validation_data=(X_test, y_test_oh), callbacks=cbs)
# Out:
# Epoch 1/100
# 150/150 [==============================] - 2s 6ms/step - loss: 2.3446 - accuracy: 0.0983 - val_loss: 2.3130 - val_accuracy: 0.1067
# Epoch 2/100
# 150/150 [==============================] - 0s 3ms/step - loss: 2.2936 - accuracy: 0.1517 - val_loss: 2.2859 - val_accuracy: 0.2467
# Epoch 3/100
# 150/150 [==============================] - 0s 3ms/step - loss: 2.2664 - accuracy: 0.2233 - val_loss: 2.2564 - val_accuracy: 0.1867
# Epoch 4/100
# 150/150 [==============================] - 0s 3ms/step - loss: 2.2135 - accuracy: 0.2150 - val_loss: 2.1861 - val_accuracy: 0.1900
# Epoch 5/100
# 150/150 [==============================] - 0s 3ms/step - loss: 2.1265 - accuracy: 0.2217 - val_loss: 2.0981 - val_accuracy: 0.1900
# Epoch 6/100
# 150/150 [==============================] - 0s 3ms/step - loss: 2.0338 - accuracy: 0.2242 - val_loss: 2.0193 - val_accuracy: 0.1900
# Epoch 7/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.9558 - accuracy: 0.2258 - val_loss: 1.9623 - val_accuracy: 0.1900
# Epoch 8/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.8970 - accuracy: 0.2275 - val_loss: 1.9190 - val_accuracy: 0.1900
# Epoch 9/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.8529 - accuracy: 0.2225 - val_loss: 1.8855 - val_accuracy: 0.1900
# Epoch 10/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.8188 - accuracy: 0.2350 - val_loss: 1.8627 - val_accuracy: 0.1900
# Epoch 11/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.7882 - accuracy: 0.2225 - val_loss: 1.8346 - val_accuracy: 0.1967
# Epoch 12/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.7640 - accuracy: 0.2683 - val_loss: 1.8362 - val_accuracy: 0.2567
# Epoch 13/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.7370 - accuracy: 0.2892 - val_loss: 1.8054 - val_accuracy: 0.2933
# Epoch 14/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.7023 - accuracy: 0.3383 - val_loss: 1.7657 - val_accuracy: 0.3233
# Epoch 15/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.6690 - accuracy: 0.3633 - val_loss: 1.7354 - val_accuracy: 0.3300
# Epoch 16/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.6321 - accuracy: 0.3683 - val_loss: 1.7000 - val_accuracy: 0.3067
# Epoch 17/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.5960 - accuracy: 0.3600 - val_loss: 1.6787 - val_accuracy: 0.3167
# Epoch 18/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.5627 - accuracy: 0.3600 - val_loss: 1.6530 - val_accuracy: 0.3000
# Epoch 19/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.5316 - accuracy: 0.3358 - val_loss: 1.6376 - val_accuracy: 0.3067
# Epoch 20/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.5055 - accuracy: 0.3667 - val_loss: 1.6246 - val_accuracy: 0.3100
# Epoch 21/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.4794 - accuracy: 0.3675 - val_loss: 1.6156 - val_accuracy: 0.3200
# Epoch 22/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.4588 - accuracy: 0.3675 - val_loss: 1.5920 - val_accuracy: 0.3133
# Epoch 23/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.4384 - accuracy: 0.3808 - val_loss: 1.5816 - val_accuracy: 0.3133
# Epoch 24/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.4216 - accuracy: 0.3867 - val_loss: 1.5694 - val_accuracy: 0.3200
# Epoch 25/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.4064 - accuracy: 0.3875 - val_loss: 1.5660 - val_accuracy: 0.3267
# Epoch 26/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3903 - accuracy: 0.3958 - val_loss: 1.5486 - val_accuracy: 0.3300
# Epoch 27/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3734 - accuracy: 0.3950 - val_loss: 1.5386 - val_accuracy: 0.3333
# Epoch 28/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3560 - accuracy: 0.4092 - val_loss: 1.5142 - val_accuracy: 0.3433
# Epoch 29/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3374 - accuracy: 0.4158 - val_loss: 1.5033 - val_accuracy: 0.3533
# Epoch 30/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3173 - accuracy: 0.4250 - val_loss: 1.4980 - val_accuracy: 0.3567
# Epoch 31/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.3003 - accuracy: 0.4300 - val_loss: 1.4841 - val_accuracy: 0.3633
# Epoch 32/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.2807 - accuracy: 0.4283 - val_loss: 1.4679 - val_accuracy: 0.3733
# Epoch 33/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.2615 - accuracy: 0.4325 - val_loss: 1.4546 - val_accuracy: 0.3667
# Epoch 34/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.2437 - accuracy: 0.4358 - val_loss: 1.4459 - val_accuracy: 0.3800
# Epoch 35/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.2260 - accuracy: 0.4375 - val_loss: 1.4330 - val_accuracy: 0.3633
# Epoch 36/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.2110 - accuracy: 0.4433 - val_loss: 1.4297 - val_accuracy: 0.3800
# Epoch 37/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1922 - accuracy: 0.4508 - val_loss: 1.4277 - val_accuracy: 0.3800
# Epoch 38/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1743 - accuracy: 0.4633 - val_loss: 1.4259 - val_accuracy: 0.3867
# Epoch 39/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1581 - accuracy: 0.4917 - val_loss: 1.3992 - val_accuracy: 0.3867
# Epoch 40/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1457 - accuracy: 0.4833 - val_loss: 1.3938 - val_accuracy: 0.3867
# Epoch 41/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1330 - accuracy: 0.5008 - val_loss: 1.3899 - val_accuracy: 0.3800
# Epoch 42/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1160 - accuracy: 0.5242 - val_loss: 1.4056 - val_accuracy: 0.3767
# Epoch 43/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1045 - accuracy: 0.5200 - val_loss: 1.3627 - val_accuracy: 0.4233
# Epoch 44/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0919 - accuracy: 0.5317 - val_loss: 1.3866 - val_accuracy: 0.4200
# Epoch 45/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0797 - accuracy: 0.5433 - val_loss: 1.3748 - val_accuracy: 0.4033
# Epoch 46/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0663 - accuracy: 0.5542 - val_loss: 1.3724 - val_accuracy: 0.4200
# Epoch 47/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0546 - accuracy: 0.5575 - val_loss: 1.3616 - val_accuracy: 0.4267
# Epoch 48/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0427 - accuracy: 0.5475 - val_loss: 1.3638 - val_accuracy: 0.3933
# Epoch 49/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0310 - accuracy: 0.5733 - val_loss: 1.3606 - val_accuracy: 0.4133
# Epoch 50/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0207 - accuracy: 0.5700 - val_loss: 1.3452 - val_accuracy: 0.3900
# Epoch 51/100
# 150/150 [==============================] - 0s 2ms/step - loss: 1.0122 - accuracy: 0.5675 - val_loss: 1.3398 - val_accuracy: 0.4133
# Epoch 52/100
# 150/150 [==============================] - 0s 3ms/step - loss: 1.0004 - accuracy: 0.6017 - val_loss: 1.3765 - val_accuracy: 0.3967
# Epoch 53/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9967 - accuracy: 0.5833 - val_loss: 1.3266 - val_accuracy: 0.4233
# Epoch 54/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9849 - accuracy: 0.5967 - val_loss: 1.3490 - val_accuracy: 0.4267
# Epoch 55/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9757 - accuracy: 0.5983 - val_loss: 1.3451 - val_accuracy: 0.4133
# Epoch 56/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9643 - accuracy: 0.6017 - val_loss: 1.3606 - val_accuracy: 0.4033
# Epoch 57/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9541 - accuracy: 0.5908 - val_loss: 1.3567 - val_accuracy: 0.4033
# Epoch 58/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9428 - accuracy: 0.6175 - val_loss: 1.3510 - val_accuracy: 0.4067
# Epoch 59/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9378 - accuracy: 0.6108 - val_loss: 1.3393 - val_accuracy: 0.4133
# Epoch 60/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9302 - accuracy: 0.6175 - val_loss: 1.3672 - val_accuracy: 0.3967
# Epoch 61/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9123 - accuracy: 0.6267 - val_loss: 1.3305 - val_accuracy: 0.4233
# Epoch 62/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9053 - accuracy: 0.6258 - val_loss: 1.3570 - val_accuracy: 0.4000
# Epoch 63/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8960 - accuracy: 0.6275 - val_loss: 1.3503 - val_accuracy: 0.4200
# Epoch 64/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8878 - accuracy: 0.6367 - val_loss: 1.3550 - val_accuracy: 0.4067
# Epoch 65/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8764 - accuracy: 0.6383 - val_loss: 1.3717 - val_accuracy: 0.4100
# Epoch 66/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8693 - accuracy: 0.6325 - val_loss: 1.3513 - val_accuracy: 0.4433
# Epoch 67/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8576 - accuracy: 0.6458 - val_loss: 1.3899 - val_accuracy: 0.4200
# Epoch 68/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8482 - accuracy: 0.6525 - val_loss: 1.3840 - val_accuracy: 0.4400
# Epoch 69/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8431 - accuracy: 0.6492 - val_loss: 1.3921 - val_accuracy: 0.4133
# Epoch 70/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8331 - accuracy: 0.6567 - val_loss: 1.3838 - val_accuracy: 0.4400
# Epoch 71/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8242 - accuracy: 0.6642 - val_loss: 1.3929 - val_accuracy: 0.4300
# Epoch 72/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8192 - accuracy: 0.6558 - val_loss: 1.4256 - val_accuracy: 0.4233
# Epoch 73/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8134 - accuracy: 0.6658 - val_loss: 1.3975 - val_accuracy: 0.4267
# Epoch 74/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.8070 - accuracy: 0.6600 - val_loss: 1.3874 - val_accuracy: 0.4433
# Epoch 75/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7995 - accuracy: 0.6683 - val_loss: 1.4078 - val_accuracy: 0.4400
# Epoch 76/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7884 - accuracy: 0.6750 - val_loss: 1.4175 - val_accuracy: 0.4433
# Epoch 77/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7810 - accuracy: 0.6733 - val_loss: 1.4131 - val_accuracy: 0.4533
# Epoch 78/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7742 - accuracy: 0.6800 - val_loss: 1.4175 - val_accuracy: 0.4600
# Epoch 79/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7624 - accuracy: 0.6875 - val_loss: 1.4024 - val_accuracy: 0.4367
# Epoch 80/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7553 - accuracy: 0.6908 - val_loss: 1.4296 - val_accuracy: 0.4567
# Epoch 81/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7476 - accuracy: 0.6908 - val_loss: 1.4310 - val_accuracy: 0.4400
# Epoch 82/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7399 - accuracy: 0.6983 - val_loss: 1.4430 - val_accuracy: 0.4500
# Epoch 83/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7309 - accuracy: 0.7017 - val_loss: 1.4534 - val_accuracy: 0.4533
# Epoch 84/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7221 - accuracy: 0.7042 - val_loss: 1.4725 - val_accuracy: 0.4633
# Epoch 85/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7197 - accuracy: 0.7108 - val_loss: 1.4462 - val_accuracy: 0.4833
# Epoch 86/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7143 - accuracy: 0.7033 - val_loss: 1.4198 - val_accuracy: 0.4867
# Epoch 87/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.7055 - accuracy: 0.7133 - val_loss: 1.4414 - val_accuracy: 0.4800
# Epoch 88/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.7250 - val_loss: 1.4603 - val_accuracy: 0.4867
# Epoch 89/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.7317 - val_loss: 1.4458 - val_accuracy: 0.4900
# Epoch 90/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.7450 - val_loss: 1.4421 - val_accuracy: 0.4867
# Epoch 91/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6473 - accuracy: 0.7450 - val_loss: 1.4704 - val_accuracy: 0.5133
# Epoch 92/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6292 - accuracy: 0.7575 - val_loss: 1.4539 - val_accuracy: 0.5133
# Epoch 93/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6268 - accuracy: 0.7542 - val_loss: 1.4605 - val_accuracy: 0.5033
# Epoch 94/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6098 - accuracy: 0.7650 - val_loss: 1.4409 - val_accuracy: 0.5267
# Epoch 95/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.7633 - val_loss: 1.4462 - val_accuracy: 0.5267
# Epoch 96/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5899 - accuracy: 0.7692 - val_loss: 1.4741 - val_accuracy: 0.5067
# Epoch 97/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.7717 - val_loss: 1.4329 - val_accuracy: 0.5300
# Epoch 98/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.7733 - val_loss: 1.4208 - val_accuracy: 0.5300
# Epoch 99/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5605 - accuracy: 0.7850 - val_loss: 1.4491 - val_accuracy: 0.5333
# Epoch 100/100
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7917 - val_loss: 1.4493 - val_accuracy: 0.5367

# %%
def plot_epochs(cbset, title=""):
    cm = plt.cm.Blues
    plt.figure(figsize=(12,3))
    plt.subplot(121)
    for i,cb in enumerate(cbset):
        plt.plot(cb.mean_per_epoch, label=cb.layer_name, color=cm(int(255*(i+1)/(len(cbset)))))
        plt.xlabel("epochs"); plt.grid(); plt.title(title+" mean")
    plt.subplot(122)
    for i,cb in enumerate(cbset):
        plt.plot(cb.std_per_epoch, label=cb.layer_name, color=cm(int(255*(i+1)/(len(cbset)))))
        plt.xlabel("epochs"); plt.grid(); plt.title(title+" std")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plot_epochs(cbs, "WEIGHTS")

# %% [markdown]
# **Registra tu solución en linea**

# %%
student.submit_task(namespace=globals(), task_id='T1');
# Out:
#                     <b>T1 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> 9NkolRoBwojIFJzyQmrEJ3N2jsdvYfXISAEs7Z6BEkl0sij9Gxuy7QUVlPm6eDj0qrpCAndJlCWb8Hey3/IhxhmV/w/TyriHjOnyaaBmYsPokdSqg5YsQh3cMGxZZQ48MStIS+uzOnbb5Anlo8plQt/mJ7unmTkhEpsxkF6VVAk=</div>

# %% [markdown]
# ## TASK 2: Activations monitoring callback

# %% [markdown]
# observe how, given a model and a certain input, we can get the activations at different layers in a very straight forward manner. If we do this before training (`.fit`) it is also ok, the model will simply use the initial random weights.

# %%
model = get_model(num_hidden_layers=3, activation="sigmoid")
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer_00_Input (Dense)      (None, 10)                7850
#
#  Layer_01_Hidden (Dense)     (None, 10)                110
#
#  Layer_02_Hidden (Dense)     (None, 10)                110
#
#  Layer_03_Hidden (Dense)     (None, 10)                110
#
#  Layer_04_Output (Dense)     (None, 10)                110
#
# =================================================================
# Total params: 8,290
# Trainable params: 8,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
activations_layer_0 = model.layers[0](X_train)
activations_layer_1 = model.layers[1](activations_layer_0)
activations_layer_0.shape, activations_layer_1.shape
# Out:
# (TensorShape([1200, 10]), TensorShape([1200, 10]))

# %% [markdown]
# Create a callback that:
#
# - when each epoch ends, feeds `self.X` into the model and retrieves the activations at the output of layer with name `self.layer_name`.
# - computes the mean and standard deviation of those activations.
# - appends them to `self.mean_per_epoch` and `self.std_per_epoch`
#
# When used with a model, at the end of any training it will contain a list of activations means and another list of activation stds, both with one element per each epoch. With this we can monitor how the activation in a specific layer progress over the training process. Tensorboard offers a similar functionality, but the goal with this task is to get acquainted with the callback mechanism.

# %%
def TrainValActivationsCallback(layer_name, X):
    class TrainValActivationsCallback_class(Callback):

        def __init__(self, layer_name, X):
            super().__init__()
            self.mean_per_epoch = []
            self.std_per_epoch = []
            self.layer_name = layer_name
            self.X = X

        def on_epoch_end(self, epoch, logs=None):
            intermediate_layer = Model(inputs = self.model.input, outputs = self.model.get_layer(self.layer_name).output)
            # feed self.X into self.model and get the activations at layer_name
            a = intermediate_layer.predict(self.X)
            # append to self.mean_per_epoch the activations mean
            self.mean_per_epoch.append(np.mean(a))
            # append to self.std_per_epoch the activations std
            self.std_per_epoch.append(np.std(a))

    return TrainValActivationsCallback_class(layer_name, X)

# %% [markdown]
# test your code with the following cell. Observe that
#
# - we create a small input dataset and model
# - invoke your callback implementation
# - your callback must contain two lists: `mean_per_epoch` and `std_per_epoch` with one single value each
# - you can check that single value with our computation. We do this computation in two different ways (1) by using explicitly the model layers; and (2) by using matrix multiplication with layers weights (`linear activation`== `no activation`)

# %%
X_in = np.random.random(size=(5,2)).astype(np.float32)
print ("input data\n", X_in)
model = get_model(input_dim=2, output_dim=3, num_hidden_layers=2, hidden_size=2, activation="linear")
layer_name = 'Layer_02_Hidden'
layer = model.get_layer(layer_name)

cb = TrainValActivationsCallback(layer.name, X_in)
cb.model = model
cb.on_epoch_end(epoch)

print ("\nactivations at", layer_name)
print ("\nactivation mean/std with your callback", cb.mean_per_epoch, cb.std_per_epoch)

l0,l1,l2,l3 = model.layers
a = l2(l1(l0(X_in))).numpy()
print ("using model layer functions            ", a.mean(), a.std())

a = X_in.dot(l0.get_weights()[0]).dot(l1.get_weights()[0]).dot(l2.get_weights()[0])
print ("manual matrix mult linear activation   ", a.mean(), a.std())
# Out:
# input data
#  [[0.70347536 0.5230367 ]
#  [0.85515755 0.10792501]
#  [0.6969189  0.05580343]
#  [0.02747858 0.5105491 ]
#  [0.30298662 0.67975193]]
# 1/1 [==============================] - 0s 105ms/step
#
# activations at Layer_02_Hidden
#
# activation mean/std with your callback [-0.08142786] [0.2524487]
# using model layer functions             -0.08142786 0.2524487
# manual matrix mult linear activation    -0.08142786 0.2524487

# %% [markdown]
# Now you can use your class to keep track of activations while training. We choose to keep track of activations with your callback for all the layers.
#
# Observe how we plot the activations progress with the data gathered by your callback. What interpretation can you give to the plots?
#
# In this case, we are creating a callback for each layer for train and for test data. If activations are similar in both train and test it may mean that the train/test splits are being treated similarly by the model.

# %%
model = get_model(num_hidden_layers=3, activation="sigmoid")
cbs_train = [TrainValActivationsCallback(i.name, X_train) for i in model.layers]
cbs_test  = [TrainValActivationsCallback(i.name, X_test) for i in model.layers]
model.fit(X_train, y_train_oh, epochs=100, batch_size=32,
          validation_data=(X_test, y_test_oh), callbacks=cbs_train+cbs_test)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 3s 58ms/step - loss: 2.3890 - accuracy: 0.1033 - val_loss: 2.3935 - val_accuracy: 0.0933
# Epoch 2/100
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 52ms/step - loss: 1.2571 - accuracy: 0.4933 - val_loss: 1.4776 - val_accuracy: 0.4133
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 52ms/step - loss: 1.2413 - accuracy: 0.5033 - val_loss: 1.4903 - val_accuracy: 0.4033
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 52ms/step - loss: 1.2269 - accuracy: 0.5125 - val_loss: 1.4351 - val_accuracy: 0.4300
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 57ms/step - loss: 1.2147 - accuracy: 0.5158 - val_loss: 1.4372 - val_accuracy: 0.4367
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 56ms/step - loss: 1.1957 - accuracy: 0.5242 - val_loss: 1.4422 - val_accuracy: 0.4267
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 58ms/step - loss: 1.1803 - accuracy: 0.5292 - val_loss: 1.4336 - val_accuracy: 0.4233
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 57ms/step - loss: 1.1664 - accuracy: 0.5242 - val_loss: 1.4465 - val_accuracy: 0.4167
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 52ms/step - loss: 1.1525 - accuracy: 0.5383 - val_loss: 1.4262 - val_accuracy: 0.4200
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 54ms/step - loss: 1.1384 - accuracy: 0.5467 - val_loss: 1.4218 - val_accuracy: 0.4233
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 56ms/step - loss: 1.1261 - accuracy: 0.5500 - val_loss: 1.4298 - val_accuracy: 0.4300
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 53ms/step - loss: 1.1129 - accuracy: 0.5617 - val_loss: 1.3953 - val_accuracy: 0.4500
# Epoch 94/100
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 56ms/step - loss: 1.1002 - accuracy: 0.5542 - val_loss: 1.4163 - val_accuracy: 0.4500
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 57ms/step - loss: 1.0863 - accuracy: 0.5583 - val_loss: 1.3800 - val_accuracy: 0.4533
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 55ms/step - loss: 1.0748 - accuracy: 0.5650 - val_loss: 1.3907 - val_accuracy: 0.4600
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 2s 56ms/step - loss: 1.0630 - accuracy: 0.5708 - val_loss: 1.3972 - val_accuracy: 0.4633
# Epoch 98/100
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 55ms/step - loss: 1.0521 - accuracy: 0.5775 - val_loss: 1.3788 - val_accuracy: 0.4667
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 58ms/step - loss: 1.0432 - accuracy: 0.5733 - val_loss: 1.3833 - val_accuracy: 0.4533
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 4ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 38/38 [==============================] - 2s 59ms/step - loss: 1.0308 - accuracy: 0.5767 - val_loss: 1.3963 - val_accuracy: 0.4667

# %%
plot_epochs(cbs_train, "ACTIVATIONS TRAIN")

# %%
plot_epochs(cbs_test, "ACTIVATIONS TEST")

# %% [markdown]
# **Registra tu solución en linea**

# %%
student.submit_task(namespace=globals(), task_id='T2');
# Out:
#                     <b>T2 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> ENsiIQRIHQj2xBQX9ujyjHGC/1rnpUTZTCQcuRUta3dNv+ijTA5PXEbaTOjRIfmDFdNxAHcRnQQT21edDJdBFH3W4la4u8SovCFMhhyMhjqCEEUAC3i0CbsGbe4f/NRkwMzJPuH1W/VMTZ9rXPkfFQz+D7M20ksK3zjrfy+kQGY=</div>
